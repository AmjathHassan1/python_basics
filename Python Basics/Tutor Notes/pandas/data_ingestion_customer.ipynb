# %%
import pandas as pd

# %%
#csv-comma separated values

# %%
df=pd.read_csv("/customer(1)",names=["id","fname","lname","age","profession","country"])
print(df.to_string())
# Out:
#           id        fname        lname  age                       profession    country
# 0    4000001     Kristina        Chung   55                            Pilot      india
# 1    4000002        Paige         Chen   74                          Teacher         uk
# 2    4000003       Sherri       Melton   34                      Firefighter         us
# 3    4000004     Gretchen         Hill   66       Computer hardware engineer      china
# 4    4000005        Karen      Puckett   74                           Lawyer     africa
# 5    4000006      Patrick         Song   42                     Veterinarian  australia
# 6    4000007        Elsie     Hamilton   43                            Pilot    ireland
# 7    4000008        Hazel       Bender   63                        Carpenter      india
# 8    4000009      Malcolm       Wagner   39                           Artist      india
# 9    4000010      Dolores   McLaughlin   60                           Writer      india
# ...

# %%
df.shape
# Out:
# (463, 6)

# %%
df.ndim
# Out:
# 2

# %%
df.head(10)
# Out:
#         id     fname       lname  age                  profession    country
# 0  4000001  Kristina       Chung   55                       Pilot      india
# 1  4000002     Paige        Chen   74                     Teacher         uk
# 2  4000003    Sherri      Melton   34                 Firefighter         us
# 3  4000004  Gretchen        Hill   66  Computer hardware engineer      china
# 4  4000005     Karen     Puckett   74                      Lawyer     africa
# 5  4000006   Patrick        Song   42                Veterinarian  australia
# 6  4000007     Elsie    Hamilton   43                       Pilot    ireland
# 7  4000008     Hazel      Bender   63                   Carpenter      india
# 8  4000009   Malcolm      Wagner   39                      Artist      india
# 9  4000010   Dolores  McLaughlin   60                      Writer      india

# %%
#iloc
df.iloc[100:151]
# Out:
#           id     fname       lname  age                       profession  \
# 100  4000101     Scott      Golden   27                          Teacher
# 101  4000102      Gene     Bowling   73    Recreation and fitness worker
# 102  4000103    Louise     Beasley   54                     Loan officer
# 103  4000104  Geoffrey       Clapp   41                     Photographer
# 104  4000105  Patricia      Abrams   51                     Veterinarian
# 105  4000106  Jennifer      Tilley   35  Agricultural and food scientist
# 106  4000107      Mary       Morse   70              Automotive mechanic
# 107  4000108     Shawn      Boykin   34                     Photographer
# 108  4000109   Vincent      Sumner   31                           Lawyer
# 109  4000110      Kurt     Cassidy   32                           Dancer
# 110  4000111     Danny    Davidson   70  Agricultural and food scientist
# 111  4000112  Charlene       Heath   26                      Electrician
# ...

# %%
df.iloc[100:151,0:3]
# Out:
#           id     fname       lname
# 100  4000101     Scott      Golden
# 101  4000102      Gene     Bowling
# 102  4000103    Louise     Beasley
# 103  4000104  Geoffrey       Clapp
# 104  4000105  Patricia      Abrams
# 105  4000106  Jennifer      Tilley
# 106  4000107      Mary       Morse
# 107  4000108     Shawn      Boykin
# 108  4000109   Vincent      Sumner
# 109  4000110      Kurt     Cassidy
# 110  4000111     Danny    Davidson
# 111  4000112  Charlene       Heath
# 112  4000113     Alice   Blanchard
# 113  4000114      Joan  McAllister
# 114  4000115     Betty    McKenzie
# 115  4000116     Danny       Byrne
# 116  4000117     Peggy   Schroeder
# 117  4000118    Leslie     Griffin
# 118  4000119  Marshall       Gross
# 119  4000120      Sara     Perkins
# 120  4000121    Martha   Robertson
# 121  4000122      Jack      Palmer
# 122  4000123     Gayle       Brady
# 123  4000124  Benjamin        Rowe
# 124  4000125   Roberta       Zhang
# 125  4000126  Patricia       Hodge
# ...

# %%
df['profession']
# Out:
# 0                           Pilot
# 1                         Teacher
# 2                     Firefighter
# 3      Computer hardware engineer
# 4                          Lawyer
#                   ...
# 458                    Politician
# 459                  Veterinarian
# 460                     Architect
# 461                  Statistician
# 462                         Actor
# Name: profession, Length: 463, dtype: object

# %%
#100,120   fname,profession,country
df.iloc[100:121][["fname","profession","country"]]
# Out:
#         fname                       profession country
# 100     Scott                          Teacher      us
# 101      Gene    Recreation and fitness worker      us
# 102    Louise                     Loan officer      us
# 103  Geoffrey                     Photographer      us
# 104  Patricia                     Veterinarian      us
# 105  Jennifer  Agricultural and food scientist      us
# 106      Mary              Automotive mechanic      us
# 107     Shawn                     Photographer      us
# 108   Vincent                           Lawyer      us
# 109      Kurt                           Dancer      us
# 110     Danny  Agricultural and food scientist      us
# 111  Charlene                      Electrician      us
# 112     Alice                        Economist      us
# 113      Joan           Engineering technician      us
# 114     Betty      Computer support specialist      us
# 115     Danny                           Dancer      us
# ...

# %%
df.sort_values(by="age",ascending=False)
# Out:
#           id     fname      lname  age           profession    country
# 324  4000325      Ruth     Harmon   75               Artist  australia
# 88   4000089    Sherri     Sutton   75        Social worker         us
# 274  4000275  Lawrence      Miles   74               Dancer     africa
# 241  4000242      Edna      Hoyle   74  Electrical engineer     africa
# 258  4000259  Margaret    Burgess   74        Social worker     africa
# ..       ...       ...        ...  ...                  ...        ...
# 291  4000292     Donna       Rice   21        Social worker  australia
# 450  4000451   Russell       Hess   21            Architect    ireland
# 348  4000349   Russell     Dalton   21       Civil engineer  australia
# 175  4000176   Kristin  Alexander   21                Coach      china
# 51   4000052   Shirley    Merritt   21             Reporter         uk
#
# [463 rows x 6 columns]

# %%
#loc
df.loc[df["country"]=="india"]
# Out:
#          id     fname       lname  age                   profession country
# 0   4000001  Kristina       Chung   55                        Pilot   india
# 7   4000008     Hazel      Bender   63                    Carpenter   india
# 8   4000009   Malcolm      Wagner   39                       Artist   india
# 9   4000010   Dolores  McLaughlin   60                       Writer   india
# 10  4000011   Francis    McNamara   47                    Therapist   india
# 11  4000012     Sandy      Raynor   26                       Writer   india
# 12  4000013    Marion        Moon   41                    Carpenter   india
# 13  4000014      Beth     Woodard   65                     Musician   india
# 14  4000015     Julia       Desai   49                     Musician   india
# 15  4000016    Jerome     Wallace   52                   Pharmacist   india
# 16  4000017      Neal    Lawrence   72  Computer support specialist   india
# ...

# %%
len(df.loc[df["age"]>70])
# Out:
# 43

# %%
#display the details of musicians from india
df.loc[(df["profession"]=="Musician") & (df["country"]=="india")].sort_values(by="age")
# Out:
#          id   fname      lname  age profession country
# 24  4000025  Claire  Gallagher   42   Musician   india
# 14  4000015   Julia      Desai   49   Musician   india
# 13  4000014    Beth    Woodard   65   Musician   india

# %%
df['country'].value_counts()
# Out:
# country
# australia    104
# africa        89
# us            78
# ireland       77
# china         56
# uk            37
# india         21
# Name: count, dtype: int64

# %%
#exploratory data analysis

# %%
df.isnull().sum()
# Out:
# id            0
# fname         0
# lname         0
# age           0
# profession    0
# country       1
# dtype: int64
