# %%
import pandas as pd

# %%
df=pd.read_csv("/content/Iris(1).csv")
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
df.drop(["Id"],axis=1,inplace=True)

# %%
sns.boxplot(data=df)
# Out:
# <Axes: >

# %%
sns.histplot(df["PetalWidthCm"],kde=True)
# Out:
# <Axes: xlabel='PetalWidthCm', ylabel='Count'>

# %%
sns.histplot(df["SepalWidthCm"],kde=True)#skewness=0,normal distribution
# Out:
# <Axes: xlabel='SepalWidthCm', ylabel='Count'>

# %%
vector=df.iloc[0,0:4].values
vector
# Out:
# array([np.float64(5.1), np.float64(3.5), np.float64(1.4), np.float64(0.2)],
#       dtype=object)

# %%
vector=df.iloc[0,0:4].astype(float).values
vector
# Out:
# array([5.1, 3.5, 1.4, 0.2])

# %%
matrix=df.iloc[:,0:4].values
matrix
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3. , 1.4, 0.1],
#        [4.3, 3. , 1.1, 0.1],
#        [5.8, 4. , 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1. , 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5. , 3. , 1.6, 0.2],
#        [5. , 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
# ...

# %%
df.shape
# Out:
# (150, 5)

# %%
matrix.T
# Out:
# array([[5.1, 4.9, 4.7, 4.6, 5. , 5.4, 4.6, 5. , 4.4, 4.9, 5.4, 4.8, 4.8,
#         4.3, 5.8, 5.7, 5.4, 5.1, 5.7, 5.1, 5.4, 5.1, 4.6, 5.1, 4.8, 5. ,
#         5. , 5.2, 5.2, 4.7, 4.8, 5.4, 5.2, 5.5, 4.9, 5. , 5.5, 4.9, 4.4,
#         5.1, 5. , 4.5, 4.4, 5. , 5.1, 4.8, 5.1, 4.6, 5.3, 5. , 7. , 6.4,
#         6.9, 5.5, 6.5, 5.7, 6.3, 4.9, 6.6, 5.2, 5. , 5.9, 6. , 6.1, 5.6,
#         6.7, 5.6, 5.8, 6.2, 5.6, 5.9, 6.1, 6.3, 6.1, 6.4, 6.6, 6.8, 6.7,
#         6. , 5.7, 5.5, 5.5, 5.8, 6. , 5.4, 6. , 6.7, 6.3, 5.6, 5.5, 5.5,
#         6.1, 5.8, 5. , 5.6, 5.7, 5.7, 6.2, 5.1, 5.7, 6.3, 5.8, 7.1, 6.3,
#         6.5, 7.6, 4.9, 7.3, 6.7, 7.2, 6.5, 6.4, 6.8, 5.7, 5.8, 6.4, 6.5,
#         7.7, 7.7, 6. , 6.9, 5.6, 7.7, 6.3, 6.7, 7.2, 6.2, 6.1, 6.4, 7.2,
#         7.4, 7.9, 6.4, 6.3, 6.1, 7.7, 6.3, 6.4, 6. , 6.9, 6.7, 6.9, 5.8,
#         6.8, 6.7, 6.7, 6.3, 6.5, 6.2, 5.9],
#        [3.5, 3. , 3.2, 3.1, 3.6, 3.9, 3.4, 3.4, 2.9, 3.1, 3.7, 3.4, 3. ,
# ...

# %%
#covariance
#-1 to 1-correlation

# %%
import numpy as np

# %%
cov_matrix=np.cov(matrix.T)
cov_matrix
# Out:
# array([[ 0.68569351, -0.03926846,  1.27368233,  0.5169038 ],
#        [-0.03926846,  0.18800403, -0.32171275, -0.11798121],
#        [ 1.27368233, -0.32171275,  3.11317942,  1.29638747],
#        [ 0.5169038 , -0.11798121,  1.29638747,  0.58241432]])

# %%
features=["sepal_len","sepal_wid","petal_len","petal_wid"]
cov_df=pd.DataFrame(cov_matrix,index=features,columns=features)
cov_df
# Out:
#            sepal_len  sepal_wid  petal_len  petal_wid
# sepal_len   0.685694  -0.039268   1.273682   0.516904
# sepal_wid  -0.039268   0.188004  -0.321713  -0.117981
# petal_len   1.273682  -0.321713   3.113179   1.296387
# petal_wid   0.516904  -0.117981   1.296387   0.582414

# %%
sns.heatmap(cov_df,annot=True)
# Out:
# <Axes: >

# %%
determinant=np.linalg.det(cov_matrix)
determinant
# Out:
# np.float64(0.001903275796739181)

# %%
eigen_values,eigen_vector=np.linalg.eig(cov_matrix)

# %%
eigen_values
# Out:
# array([4.22484077, 0.24224357, 0.07852391, 0.02368303])

# %%
eigen_vector
# Out:
# array([[ 0.36158968, -0.65653988, -0.58099728,  0.31725455],
#        [-0.08226889, -0.72971237,  0.59641809, -0.32409435],
#        [ 0.85657211,  0.1757674 ,  0.07252408, -0.47971899],
#        [ 0.35884393,  0.07470647,  0.54906091,  0.75112056]])

# %%
import numpy as np

# %%
a=np.array([[2,0],[0,3]])
a
# Out:
# array([[2, 0],
#        [0, 3]])

# %%
eigenvalues,eigenvectors=np.linalg.eig(a)

# %%
eigenvalues
# Out:
# array([2., 3.])

# %%
eigenvectors
# Out:
# array([[1., 0.],
#        [0., 1.]])

# %%
df.skew(numeric_only=True)
# Out:
# SepalLengthCm    0.314911
# SepalWidthCm     0.334053
# PetalLengthCm   -0.274464
# PetalWidthCm    -0.104997
# dtype: float64

# %%
#coin toss
s={H,T}
p(h)=1/2=0.5
p(t)=1/2=0.5
p(t)+p(h)=0.5+0.5=1

# %%
s={1,2,3,4,5,6}
p(1)=1/6
p(even)={2,4,6}=3/6=1/2
p(odd)=1/2

# %%
#no.of students   10,12,22,--discrete
#weight     140.12,140.123,140.1234,---conti
